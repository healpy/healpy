# %%
import healpy as hp
from healpy import newvisufunc

# %%
file='wmap_band_iqumap_r9_7yr_W_v4_udgraded32_masked_smoothed10deg_fortran.fits'

# %%
map = hp.fitsfunc.read_map('/usr/local/lib/python3.7/site-packages/healpy/test/data/'+file)
# Out:
# /usr/local/lib/python3.7/site-packages/healpy/fitsfunc.py:369: UserWarning: If you are not specifying the input dtype and using the default np.float64 dtype of read_map(), please consider that it will change in a future version to None as to keep the same dtype of the input file: please explicitly set the dtype if it is important to you.
#   "If you are not specifying the input dtype and using the default "
# /usr/local/lib/python3.7/site-packages/healpy/fitsfunc.py:391: UserWarning: NSIDE = 32
#   warnings.warn("NSIDE = {0:d}".format(nside))
# /usr/local/lib/python3.7/site-packages/healpy/fitsfunc.py:400: UserWarning: ORDERING = RING in fits file
#   warnings.warn("ORDERING = {0:s} in fits file".format(ordering))
# /usr/local/lib/python3.7/site-packages/healpy/fitsfunc.py:428: UserWarning: INDXSCHM = IMPLICIT
#   warnings.warn("INDXSCHM = {0:s}".format(schm))

# %%
# classic healpy mollweide projections plot
# other matplotlib projections are possible, such as: "aitoff","hammer",lambert"
newvisufunc.projview(map, coord=['G'],flip='astro', projection_type="mollweide")
# Out:
# mollweide

# %%
# classic healpy mollweide projections plot with graticule
newvisufunc.projview(map, coord=['G'],graticule=True, graticule_labels=True, projection_type="mollweide")
# Out:
# mollweide

# %%
# classic healpy mollweide projections plot with graticule and axis labels
newvisufunc.projview(map, coord=['G'],graticule=True, graticule_labels=True,
                    unit='cbar label',xlabel='xlabel',ylabel='ylabel', cb_orientation='horizontal',
                    projection_type="mollweide")
# Out:
# mollweide

# %%
# classic healpy mollweide projections plot with graticule and axis labels and vertical color bar
newvisufunc.projview(map, coord=['G'],graticule=True, graticule_labels=True,
                    unit='cbar label',xlabel='xlabel',ylabel='ylabel', cb_orientation='vertical',
                    projection_type="mollweide")
# Out:
# mollweide

# %%
# classic healpy mollweide projections plot with graticule and axis labels and vertical color bar, when min and max is set
# to be different than the min, max of the data, the colorbar is extended
# with title
newvisufunc.projview(map, coord=['G'],graticule=True, graticule_labels=True,
                    unit='cbar label',xlabel='xlabel',ylabel='ylabel',
                    cb_orientation='vertical',min=-0.05,max=0.05,latitude_grid_spacing=45,
                    projection_type="mollweide",title='Mollweide projection')
# Out:
# mollweide

# %%
# hammer view plot with graticule and axis labels and vertical color bar, when min and max is set
# to be different than the min, max of the data, the colorbar is extended
newvisufunc.projview(map, coord=['G'],graticule=True, graticule_labels=True,
                    unit='cbar label',xlabel='xlabel',ylabel='ylabel',
                    cb_orientation='vertical',min=-0.05,max=0.05,latitude_grid_spacing=30,
                    projection_type="hammer",title='Hammer projection')
# Out:
# hammer

# %%
# aitoff view plot with graticule and axis labels and vertical color bar, when min and max is set
# to be different than the min, max of the data, the colorbar is extended
newvisufunc.projview(map, coord=['G'],graticule=True, graticule_labels=True,
                    unit='cbar label',xlabel='xlabel',ylabel='ylabel',
                    cb_orientation='vertical',min=-0.05,max=0.05,latitude_grid_spacing=30,
                    projection_type="aitoff",title='Aitoff projection')
# Out:
# aitoff

# %%
# cartview, clasic healpy
newvisufunc.projview(map, coord=['G'], projection_type="cart")
# Out:
# cart

# %%
# cartview, with labels and graticule
newvisufunc.projview(map, coord=['G'],graticule=True, graticule_labels=True,
                    unit='cbar label',xlabel='xlabel',ylabel='ylabel',
                    cb_orientation='horizontal',
                    projection_type="cart", title='Cart projection' )
# Out:
# cart

# %%
# cartview, with labels and graticule
newvisufunc.projview(map, coord=['G'],graticule=True, graticule_labels=True,
                    unit='cbar label',xlabel='xlabel',ylabel='ylabel',
                    cb_orientation='horizontal',projection_type="cart")
# Out:
# cart

# %%
# cartview, with labels and graticule, vertical cbar
newvisufunc.projview(map, coord=['G'],graticule=True, graticule_labels=True,
                    unit='cbar label',xlabel='xlabel',ylabel='ylabel',
                    cb_orientation='vertical',
                    projection_type="cart")
# Out:
# cart

# %%
# 3d view
newvisufunc.projview(map, coord=['G'],hold=False,graticule=True, graticule_labels=True,
                    unit='cbar label',ylabel='mollweide',xlabel='mollweide', cb_orientation='horizontal',
                    projection_type='3d', title= '3D projection')
# Out:
# 3d

# %%
# 3d view, vertical cbar
newvisufunc.projview(map, coord=['G'],hold=False,graticule=True, graticule_labels=True,
                    projection_type="3d",unit='cbar label',xlabel='xlabel',ylabel='ylabel',
                     cb_orientation='vertical')
# Out:
# 3d

# %%
# polar view
newvisufunc.projview(map, coord=['G'],graticule=True, graticule_labels=True, unit='cbar label', 
                     cb_orientation='horizontal', projection_type="polar", title='Polar projection')
# Out:
# polar

# %%
# polar view, vertical cbar
newvisufunc.projview(map, coord=['G'],graticule=True, graticule_labels=True, unit='cbar label',
                     cb_orientation='vertical', projection_type="polar")
# Out:
# polar

# %%
# polar view, override example
newvisufunc.projview(map, coord=['G'],hold=False,graticule=True, graticule_labels=True,flip='astro',
                    projection_type="polar",unit='cbar label', cb_orientation='horizontal',
                    override_plot_properties=[0.2,0.01,-8,8,0.63])
# Out:
# Overriding default plot properies: shrink= 0.4, pad=0.01, lpad=0,width=12,r=0.63, to one:  shrink= 0.2, pad=0.01, lpad=-8,width=8,r=0.63
# polar

# %%
# return only data
# [longitude,  latitude, grid_map]
# longitude,  latitude are 1D arrays to convert them to 2D arrays for the plot use np.meshgrid(longitude,  latitude)
# longtitude goes from -pi to pi (-180 to 180 in degs)
# latitude goes from -pi/2 to pi/2 (-90 to 90 in degs)

longitude,  latitude, grid_map = newvisufunc.projview(map, coord=['G'],return_only_data=True)
print(longitude.shape)
print(latitude.shape)
print(grid_map.shape)
# Out:
# (1000,)
# (500,)
# (500, 1000)
